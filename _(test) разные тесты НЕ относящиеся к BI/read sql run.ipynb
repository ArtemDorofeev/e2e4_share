# %%
# #  запуск всех модулей кроме (НЕ КАНАЮТ ПЕРЕМЕННЫЕ! надо через magic тогда все четка)
# def exec_f(path_exec):
#     with open( path_exec,'r') as exec_f:
#         exec(exec_f.read())
# [ exec_f(j) for j in glob.glob(r"/var/lib/private/**/_ Additions/*", recursive=True) if 'Imports_Formats' not in j];

# %%
# magic
############################################################

# magic не запускаются с посмощью run !! поэтому отдельно будут тут! # %magic # посмотреть список magic команд
# %matplotlib inline


# run files
# %run /home/slebedev/"_Additions"/Imports_Formats.py

# %run /home/slebedev/"_Additions"/Connecting_bi_admin.py

# %run /home/slebedev/"_Additions"/Date_gen.py

# %run /home/slebedev/"_Additions"/xx.py


############################## End ##############################
print( abs_path )
# Out:
# /home/slebedev/

# %%
df_date_m['start'][1]
# df_date_m df_date_Y
# Out:
# '2017-02-01'

# %%
for i in df_date_Y.iloc[:1,:].values:
        print(f'{i[0]} || {i[1]}')
# Out:
# 2017-01-01 || 2017-12-31

# %%
qwe.replace('DATE_START_replce', f'{i[0]}').replace('DATE_END_replce', f'{i[1]}')
# Out:
# '\n--/*10.06.2021 ФОН ju (+даты по статусу На складе выдачи)  + тествозвраты*/ 2019-01-13  2021-02-27 \n\n/* В ВОЗВРАТАХ ЧИСТО ТОВАРЫ НЕТ СЕРВИСА И ТД\n * 08.06  ФОН ju + возвраты\t08.06.2021 \n * чист себес, дата с ju, + возвраты\n * \n * */\n\nWITH params AS MATERIALIZED (\nselect\n\n     (2017-01-01 || \' 00:00:00\')::timestamp    frm \n    ,(2017-12-31 || \' 23:59:59\')::timestamp    til\n\t\n)\n\n, \nwarranty_opentech as (\nselect distinct \n-- 751 705 029.15\n-- 180464  2000-01-01 2021-12-31   751 705 029 совпадает (вместе  pa и ww если p.id и distinct)\n-- 751 705 030 (округление) ексель сходится (возвраты динамические суммы меняются но сходимость ДОЛЖНА БЫТЬ!)\n    ww.id_store_item "id принятой по ЗН железяки"   \n\t,p.sum "Сумма возврата"\t\t\t\t\t\t\t\n\t,p.id "id платежа"    \n\n--    ,p.customer_id "p.customer_id (кто платил?)"\n--    ,p.type\n--    ,p.date_po "Дата поступления денег (возврат)"\n--    ,p.purpose "Назначение платежа"\n--    ,ww.number "Номер ЗН"           
# ...

# %%
# for i in df_date_Y.iloc[:1,:].values:
#         print(f'{i[0]} || {i[1]}')
print(f'{i[0]} || {i[1]}')
with psycopg2.connect(dbname=database, user=user, password=password, host=host) as cnxn:
    df = pd.read_sql_query(qwe.replace('DATE_START_replce', f'{i[0]}').replace('DATE_END_replce', f'{i[1]}'), cnxn)

df
# Out:
# ---------------------------------------------------------------------------
# InvalidDatetimeFormat                     Traceback (most recent call last)
# /usr/local/lib64/python3.6/site-packages/pandas/io/sql.py in execute(self, *args, **kwargs)
#    1680         try:
# -> 1681             cur.execute(*args, **kwargs)
#    1682             return cur
#
# InvalidDatetimeFormat: invalid input syntax for type timestamp: "2015 00:00:00"
#
#
# The above exception was the direct cause of the following exception:
#
# DatabaseError                             Traceback (most recent call last)
# <ipython-input-8-b188441596c0> in <module>
#       3
#       4 with psycopg2.connect(dbname=database, user=user, password=password, host=host) as cnxn:
# ----> 5     df = pd.read_sql_query(qwe.replace('DATE_START_replce', f'{i[0]}').replace('DATE_END_replce', f'{i[1]}'), cnxn)
#       6
#       7 df
#
# ...

# %%
# читаем sql file (и подставляем даты)
path_SQL_warranty_fon = glob.glob( abs_path  + r"SQL_warranty_fon.sql", recursive=True)[0]

with open( path_SQL_warranty_fon, "r", encoding = "utf-8" ) as sql_file:
    
    for i in df_date_Y.iloc[:1,:].values:
        print(f'{i[0]} || {i[1]}')
        sql_query = sql_file.read().replace('DATE_START_replce', f'{i[0]}').replace('DATE_END_replce', f'{i[1]}')
        print( sql_query )
        
        with psycopg2.connect(dbname=database, user=user, password=password, host=host) as cnxn:
            df = pd.read_sql_query(sql_query, cnxn)

df


# sql_file _ SQL query files
# Out:
# 2017-01-01 || 2017-12-31
# --/*10.06.2021 ФОН ju (+даты по статусу На складе выдачи)  + тествозвраты*/ 2019-01-13  2021-02-27
#
# /* В ВОЗВРАТАХ ЧИСТО ТОВАРЫ НЕТ СЕРВИСА И ТД
#  * 08.06  ФОН ju + возвраты    08.06.2021
#  * чист себес, дата с ju, + возвраты
#  *
#  * */
#
# WITH params AS MATERIALIZED (
# select
#
#     ( '2017-01-01' || ' 00:00:00')::timestamp    frm
#     ,( '2017-12-31' || ' 23:59:59')::timestamp    til
#
# )
#
# ,
# warranty_opentech as (
# select distinct
# -- 751 705 029.15
# -- 180464  2000-01-01 2021-12-31   751 705 029 совпадает (вместе  pa и ww если p.id и distinct)
# -- 751 705 030 (округление) ексель сходится (возвраты динамические суммы меняются но сходимость ДОЛЖНА БЫТЬ!)
#     ww.id_store_item "id принятой по ЗН железяки"
#     ,p.sum "Сумма возврата"
#     ,p.id "id платежа"
#
# --    ,p.customer_id "p.customer_id (кто платил?)"
# --    ,p.type
# --    ,p.date_po "Дата поступления денег (возврат)"
# --    ,p.purpose "Назначение платежа"
# ...

# %%
df
# Out:
#        ID клиента ФИО оформившего заказ Наименование клиента Тип клиента  \
# 0            1.00         Азгалдян А.Ю.         частное лицо          ФЛ
# 1            1.00         Азгалдян А.Ю.         частное лицо          ФЛ
# 2            1.00           Алеев Ф. Р.         частное лицо          ФЛ
# 3            1.00         Арбузов Д. Ю.         частное лицо          ФЛ
# 4            1.00         Бабешко А. В.         частное лицо          ФЛ
# ...           ...                   ...                  ...         ...
# 23297         nan                  None                 None          ФЛ
# 23298         nan                  None                 None          ФЛ
# 23299         nan                  None                 None          ФЛ
# 23300         nan                  None                 None          ФЛ
# 23301         nan                  None                 None          ФЛ
#
#       Классификация   инн  Отсрочка, дни  Отсрочка факт, дни ОКВЭД Отрасль  \
# ...

# %%
# Out:
# 10.598588585853577

# %%
# to_csv
df.to_csv(abs_path + r'_ DATA/' + 'warranty.csv', sep='☺',  index=False) # cp-1251 encoding='UTF-8', engine='xlsxwriter'

# %%
glob.glob( abs_path + r"**/"  + r"SQL_warranty_fon.sql", recursive=True)[0]
# Out:
# '/home/slebedev/_  SQL query files/SQL_warranty_fon.sql'

# %%
abs_path
# Out:
# '/home/slebedev/'

# %%
2+2
# Out:
# 4

# %%
print('stfjhsrt')
# Out:
# stfjhsrt
