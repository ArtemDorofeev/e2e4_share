# %%
# magic
get_ipython().run_line_magic('matplotlib', 'inline')
# run files
get_ipython().run_line_magic('run', '/srv/jhub/share/._Additions/Import_libs.py')
get_ipython().run_line_magic('run', '/srv/jhub/share/._Additions/Connecting_.py')
get_ipython().run_line_magic('run', '/srv/jhub/share/._Additions/my_script.py')
get_ipython().run_line_magic('run', '/srv/jhub/share/._Additions/Date_gen.py')
get_ipython().run_line_magic('run', '/srv/jhub/share/._Additions/xx.py')

# print
###########################
# print(
# df_test_xx.shape, '\n'
# ,abs_path, '\n' # abs_path - путь до шары (видна всем езерам - '/srv/jhub/share/')
# ,path_OUT_dbDATA, '\n'
# ,date_start, date_end, '\n'
# )
############################## End ##############################

# В НАЧАЛЕ СКРИПТА АВТОЗАПУСКА
# logs crontab АВТОЗАПУСК
# start_datetime = datetime.datetime.today()
# name_file = r'[АВТОЗАПУСК] Источники для BI (Продажи_).py'
# path_ipy = r"/opt/anaconda3/envs/jupyter_env/bin/ipython" 
# path_file = fr"/home/slebedev/jhub-analytics/'_ Analytics department'/'Источники для BI (Продажи)'/'{name_file}'" 
# log_info = []

###########################

path_SQL_sales = glob.glob(abs_path + r'**/' + r'*test*АВТОЗАПУСК] Источники для BI (Продажи_).sql', recursive=True)[0]
print(f'path_SQL_sales - {path_SQL_sales}')

date_df_start = df_date_m['start'][0]
date_df_end = df_date_m.iloc[-1, -1]
# date_df_start, date_df_end, df_date_m.iloc[-2:, :]

# public_link = '''https://nextcloud.e2e4.ru/apps/files/?dir=/Public/Отчеты%20(выгрузка%20jupyter%20notebooks)&fileid=2018892'''
AmazonS3_folder_Public = r'/Public/Отчеты (выгрузка jupyter notebooks)'
AmazonS3_path_to_file = r'/ДЛЯ ТЕСТОВ/BI (all 17-now)/' 
# print('AmazonS3_file_name - ', AmazonS3_file_name, '/nAmazonS3_full_path - ', AmazonS3_full_path)
Amazon_owncloud = owncloud.Client('https://nextcloud.e2e4.ru')
Amazon_owncloud.login(loginAtlassianjhubAdmin, passwordAtlassianjhubAdmin)
### Amazon_owncloud.mkdir('testdir')
# Out:
# path_SQL_sales - /home/slebedev/jhub-analytics/_ Analytics department/Источники для BI (Продажи)/tests/(test) [АВТОЗАПУСК] Источники для BI (Продажи_).sql

# %%
for i in df_date_m.iloc[ 49 :  , : ].values:
    print(f'{i[0]} || {i[1]}')
# Out:
# 2021-02-01 || 2021-02-28
# 2021-03-01 || 2021-03-31
# 2021-04-01 || 2021-04-30
# 2021-05-01 || 2021-05-31
# 2021-06-01 || 2021-06-30
# 2021-07-01 || 2021-07-31
# 2021-08-01 || 2021-08-31
# 2021-09-01 || 2021-09-30
# 2021-10-01 || 2021-10-31
# 2021-11-01 || 2021-11-30
# 2021-12-01 || 2021-12-31
# 2022-01-01 || 2022-01-31
# 2022-02-01 || 2022-02-28
# 2022-03-01 || 2022-03-31
# 2022-04-01 || 2022-04-30
# 2022-05-01 || 2022-05-31
# 2022-06-01 || 2022-06-30

# %%
## идем по датам, коннектимся, читаем sql file, подставляем даты
df_fon = pd.DataFrame()
for i in df_date_m.iloc[ 49 :  , : ].values:
# for i in df_date_m.iloc[-20:,:].values:
    df_part = 0
    print(f'{i[0]} || {i[1]}')
#   читаем sql file
    with open( path_SQL_sales, "r", encoding = "utf-8" ) as sql_file_sales:
#       коннектимся 
        with psycopg2.connect(dbname=database, user=user, password=password, host=host) as cnxn:
#           подставляем даты
            print('подставляем даты, выгружаем')
            df_fon = pd.read_sql_query(sql_file_sales.read().replace('DATE_START_replce', f'{i[0]}').replace('DATE_END_replce', f'{i[1]}'), cnxn) 
            print('✔ .read_sql_query')
#     log_info.append( (i, df_fon.shape) )
    if df_fon.shape[0] != 0:
#         делим на файлы если больше ляма строк
        shape_list_temp = list(range(0, df_fon.shape[0], exc_limit_list))
        shape_list = shape_list_temp + [shape_list_temp[-1] + (df_fon.shape[0] % exc_limit_list)]
    #     print(df_fon.shape)
        for z in range(len(shape_list + [0,0]))[:-3]:
            AmazonS3_file_name = fr'Источники для BI (Продажи) {i[0]} - {i[1]} {df_part}' # ({getpass.getuser()})
            df_part += 1
            AmazonS3_full_path = AmazonS3_folder_Public + AmazonS3_path_to_file + AmazonS3_file_name
#             print( shape_list[i:i+1][0], shape_list[i+1:i+2][0] )
            print( f'df shpe - {df_fon[ shape_list[z:z+1][0] : shape_list[z+1:z+2][0] ].shape[0]} - to_excel' )

        #   to_excel
            df_fon[ shape_list[z:z+1][0] : shape_list[z+1:z+2][0] ].to_excel(temp_tmp + AmazonS3_file_name + '.xlsx',  index=False, encoding='cp-1251') 
            print('✔ .to_excel')
        #   to_csv 
        #     df_fon.to_csv(path_OUT_dbDATA + r'Фоновый отчет по выручке (по дате продажи) с возвратами/' \
        #         + fr'Источники для BI (Продажи) { i[0] } { i[1] } .csv', sep='☺',  index=False) # cp-1251 encoding='UTF-8', engine='xlsxwriter'
        #   .to_pickle
            df_fon[ shape_list[z:z+1][0] : shape_list[z+1:z+2][0] ].to_pickle(temp_tmp + AmazonS3_file_name + '.pkl', compression='zip') 
            print('✔ .to_pickle')

            Amazon_owncloud.put_file( # полный путь и там и там!!! 
                        AmazonS3_full_path + '.xlsx', temp_tmp + AmazonS3_file_name + '.xlsx')
            print( f'✔ Файл записан в облако\n {AmazonS3_full_path}.xlsx')  

            Amazon_owncloud.put_file( # полный путь и там и там!!! 
                        AmazonS3_full_path + '.pkl', temp_tmp + AmazonS3_file_name + '.pkl'
                        ) 
            print( f'✔ Файл записан в облако\n {AmazonS3_full_path}.pkl') 

            os.remove(temp_tmp + AmazonS3_file_name + '.xlsx')
            os.remove(temp_tmp + AmazonS3_file_name + '.pkl')
            print('✔ os.remove')
        #     print(df_fon) 
            print(f"{datasize.DataSize(sys.getsizeof(df_fon)):MiB}", '(MiB)\n' )

    else:
        print( df_fon, '-- df.shape =', df_fon.shape)

# В КОНЦЕ СКРИПТА АВТОЗАПУСКА!
# print('log_info')

# print( log_info[0] )
# print( log_info[0][0] )
# print( log_info[0][1] )
# print( log_info[0][2] )

# log_info = str(log_info[0][0]) + ''' ''' + str(log_info[0][1]) + ''' ''' + str(log_info[0][2]) 
# cron_logs( start_datetime=start_datetime, name_file=name_file, path_ipy=path_ipy, path_file=path_file, log_info=log_info )
# print('✔ cron_logs\n\n')
# Out:
# 2021-02-01 || 2021-02-28
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 529266 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-02-01 - 2021-02-28 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-02-01 - 2021-02-28 0.pkl
# ✔ os.remove
# 705.8160333633423MiB (MiB)
#
# 2021-03-01 || 2021-03-31
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 1000000 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-03-01 - 2021-03-31 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-03-01 - 2021-03-31 0.pkl
# ✔ os.remove
# 1414.9326553344727MiB (MiB)
#
# df shpe - 275991 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-03-01 - 2021-03-31 1.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-03-01 - 2021-03-31 1.pkl
# ✔ os.remove
# 1446.4487524032593MiB (MiB)
#
# 2021-04-01 || 2021-04-30
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 626402 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-04-01 - 2021-04-30 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-04-01 - 2021-04-30 0.pkl
# ✔ os.remove
# 830.5514240264893MiB (MiB)
#
# 2021-05-01 || 2021-05-31
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 466550 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-05-01 - 2021-05-31 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-05-01 - 2021-05-31 0.pkl
# ✔ os.remove
# 637.8421649932861MiB (MiB)
#
# 2021-06-01 || 2021-06-30
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 564785 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-06-01 - 2021-06-30 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-06-01 - 2021-06-30 0.pkl
# ✔ os.remove
# 740.3329381942749MiB (MiB)
#
# 2021-07-01 || 2021-07-31
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 509260 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-07-01 - 2021-07-31 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-07-01 - 2021-07-31 0.pkl
# ✔ os.remove
# 686.4131803512573MiB (MiB)
#
# 2021-08-01 || 2021-08-31
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 589033 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-08-01 - 2021-08-31 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-08-01 - 2021-08-31 0.pkl
# ✔ os.remove
# 779.1935138702393MiB (MiB)
#
# 2021-09-01 || 2021-09-30
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 706013 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-09-01 - 2021-09-30 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-09-01 - 2021-09-30 0.pkl
# ✔ os.remove
# 928.1510000228882MiB (MiB)
#
# 2021-10-01 || 2021-10-31
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 637470 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-10-01 - 2021-10-31 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-10-01 - 2021-10-31 0.pkl
# ✔ os.remove
# 836.5569925308228MiB (MiB)
#
# 2021-11-01 || 2021-11-30
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 872380 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-11-01 - 2021-11-30 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-11-01 - 2021-11-30 0.pkl
# ✔ os.remove
# 1168.959186553955MiB (MiB)
#
# 2021-12-01 || 2021-12-31
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 622803 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-12-01 - 2021-12-31 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2021-12-01 - 2021-12-31 0.pkl
# ✔ os.remove
# 853.9911403656006MiB (MiB)
#
# 2022-01-01 || 2022-01-31
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 468167 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-01-01 - 2022-01-31 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-01-01 - 2022-01-31 0.pkl
# ✔ os.remove
# 631.1167573928833MiB (MiB)
#
# 2022-02-01 || 2022-02-28
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 566347 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-02-01 - 2022-02-28 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-02-01 - 2022-02-28 0.pkl
# ✔ os.remove
# 766.1672887802124MiB (MiB)
#
# 2022-03-01 || 2022-03-31
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 903466 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-03-01 - 2022-03-31 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-03-01 - 2022-03-31 0.pkl
# ✔ os.remove
# 1162.1762266159058MiB (MiB)
#
# 2022-04-01 || 2022-04-30
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 434900 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-04-01 - 2022-04-30 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-04-01 - 2022-04-30 0.pkl
# ✔ os.remove
# 582.7962026596069MiB (MiB)
#
# 2022-05-01 || 2022-05-31
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 444410 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-05-01 - 2022-05-31 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-05-01 - 2022-05-31 0.pkl
# ✔ os.remove
# 560.4533758163452MiB (MiB)
#
# 2022-06-01 || 2022-06-30
# подставляем даты, выгружаем
# ✔ .read_sql_query
# df shpe - 36330 - to_excel
# ✔ .to_excel
# ✔ .to_pickle
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-06-01 - 2022-06-30 0.xlsx
# ✔ Файл записан в облако
#  /Public/Отчеты (выгрузка jupyter notebooks)/ДЛЯ ТЕСТОВ/BI (all 17-now)/Источники для BI (Продажи) 2022-06-01 - 2022-06-30 0.pkl
# ✔ os.remove
# 41.818190574645996MiB (MiB)
