# %% [markdown]
# # !!проверка [АВТОЗАПУСК] Источники для BI (Продажи_).py [АВТОЗАПУСК] Источники для BI (Продажи_).sql

# %% [markdown]
# # проверка почему вывалились заказы с датой отгрузки седня когда дата должна быть вчера???
# вопрос решен
# *ответ:* потому что кронтаб грузит ночью и надо в питоне на последние 2 мес исключить текущ дату и все (в питоне не скулах!)

# %% [markdown]
# # тесты

# %%
# magic    
get_ipython().run_line_magic('matplotlib', 'inline')
# run files
get_ipython().run_line_magic('run', '/srv/jhub/share/._Additions/Import_libs.py')
get_ipython().run_line_magic('run', '/srv/jhub/share/._Additions/Connecting_.py')
get_ipython().run_line_magic('run', '/srv/jhub/share/._Additions/my_script.py')
get_ipython().run_line_magic('run', '/srv/jhub/share/._Additions/Date_gen.py')
get_ipython().run_line_magic('run', '/srv/jhub/share/._Additions/xx.py')

# print
###########################
# print(
# df_test_xx.shape, '\n'
# ,abs_path, '\n' # abs_path - путь до шары (видна всем езерам - '/srv/jhub/share/')
# ,path_OUT_dbDATA, '\n'
# ,date_start, date_end, '\n'
# )
############################## End ##############################

# В НАЧАЛЕ СКРИПТА АВТОЗАПУСКА
# logs crontab АВТОЗАПУСК
start_datetime = datetime.datetime.today()
name_file = r'[АВТОЗАПУСК] Источники для BI (Продажи_)-last2month.py'
path_ipy = r"/opt/anaconda3/envs/jupyter_env/bin/ipython" 
path_file = fr"/home/slebedev/jhub-analytics/'_ Analytics department'/'Источники для BI (Продажи)'/'{name_file}'" 
log_info = []

###########################

# %%
path_SQL_sales = glob.glob(abs_path + r'**/' + r"*АВТОЗАПУСК] Источники для BI (Продажи_).sql", recursive=True)[0]
print(f'path_SQL_sales - {path_SQL_sales}')

date_df_start = df_date_m['start'][0]
date_df_end = df_date_m.iloc[-1, -1]
# date_df_start, date_df_end, df_date_m.iloc[-2:, :]

# public_link = '''https://nextcloud.e2e4.ru/apps/files/?dir=/Public/Отчеты%20(выгрузка%20jupyter%20notebooks)&fileid=2018892'''
AmazonS3_folder_Public = r'/Public/Отчеты (выгрузка jupyter notebooks)'
AmazonS3_path_to_file = r'/Источники для BI/Продажи_/'
# print('AmazonS3_file_name - ', AmazonS3_file_name, '/nAmazonS3_full_path - ', AmazonS3_full_path)
Amazon_owncloud = owncloud.Client('https://nextcloud.e2e4.ru')
Amazon_owncloud.login(loginAtlassianjhubAdmin, passwordAtlassianjhubAdmin)
### Amazon_owncloud.mkdir('testdir')
# Out:
# path_SQL_sales - /home/slebedev/jhub-analytics/_ Analytics department/Источники для BI (Продажи)/ [АВТОЗАПУСК] Источники для BI (Продажи_).sql

# %%
df_date_m.iloc[-2:,:].values
# Out:
# array([['2022-11-01', '2022-11-30'],
#        ['2022-12-01', '2022-12-31']], dtype=object)

# %%
## идем по датам, коннектимся, читаем sql file, подставляем даты
df_fon = pd.DataFrame()
for i in df_date_m.iloc[-1:,:].values:
    AmazonS3_file_name = fr'Источники для BI (Продажи) {i[0]} - {i[1]}' # ({getpass.getuser()})
    AmazonS3_full_path = AmazonS3_folder_Public + AmazonS3_path_to_file + AmazonS3_file_name

    print(f'{i[0]} || {i[1]}')
#   читаем sql file
    with open( path_SQL_sales, "r", encoding = "utf-8" ) as sql_file_sales:
#       коннектимся 
        with psycopg2.connect(dbname=database, user=user, password=password, host=host) as cnxn:
#           подставляем даты
            print('подставляем даты, выгружаем')
            df_fon = pd.read_sql_query(sql_file_sales.read().replace('DATE_START_replce', f'{i[0]}').replace('DATE_END_replce', f'{i[1]}'), cnxn) 
            print('✔ .read_sql_query')
            
#     log_info.append( (i, df_fon.shape) )
#     if df_fon.shape[0] != 0:
#     #   to_excel
#         df_fon.to_excel(temp_tmp + AmazonS3_file_name + '.xlsx',  index=False, encoding='cp-1251') 
#         print('✔ .to_excel')
#     #   to_csv 
#     #     df_fon.to_csv(path_OUT_dbDATA + r'Фоновый отчет по выручке (по дате продажи) с возвратами/' \
#     #         + fr'Источники для BI (Продажи) { i[0] } { i[1] } .csv', sep='☺',  index=False) # cp-1251 encoding='UTF-8', engine='xlsxwriter'
#     #   .to_pickle
#         df_fon.to_pickle(temp_tmp + AmazonS3_file_name + '.pkl', compression='zip') 
#         print('✔ .to_pickle')

#         Amazon_owncloud.put_file( # полный путь и там и там!!! 
#                     AmazonS3_full_path + '.xlsx', temp_tmp + AmazonS3_file_name + '.xlsx')
#         print( f'✔ Файл записан в облако\n {AmazonS3_full_path}.xlsx')  

#         Amazon_owncloud.put_file( # полный путь и там и там!!! 
#                     AmazonS3_full_path + '.pkl', temp_tmp + AmazonS3_file_name + '.pkl'
#                     ) 
#         print( f'✔ Файл записан в облако\n {AmazonS3_full_path}.pkl') 

#         os.remove(temp_tmp + AmazonS3_file_name + '.xlsx')
#         os.remove(temp_tmp + AmazonS3_file_name + '.pkl')
#         print('✔ os.remove')
#     #     print(df_fon) 
#         print(f"{datasize.DataSize(sys.getsizeof(df_fon)):MiB}", '(MiB)\n\n' )

#     else:
#         print( df_fon, '-- df.shape =', df_fon.shape)

# # В КОНЦЕ СКРИПТА АВТОЗАПУСКА!
# print('log_info')

# print( log_info[0] )
# print( log_info[0][0] )
# print( log_info[0][1] )
# print( log_info[0][2] )

# log_info = str(log_info[0][0]) + ''' ''' + str(log_info[0][1]) + ''' ''' + str(log_info[0][2]) 
# cron_logs( start_datetime=start_datetime, name_file=name_file, path_ipy=path_ipy, path_file=path_file, log_info=log_info )
# print('✔ cron_logs\n\n')
df_fon
# Out:
# 2022-12-01 || 2022-12-31
# подставляем даты, выгружаем
# ✔ .read_sql_query
#       ID клиента   e2e4 ID  ID оформившего заказ  Ответственный менеджер  \
# 0         790217       NaN                1518.0                     NaN
# 1          11927    2518.0                1017.0                     NaN
# 2         855215       NaN                1518.0                     NaN
# 3          39332       NaN                  89.0                     NaN
# 4         594732  412238.0                1017.0                   325.0
# ...          ...       ...                   ...                     ...
# 34006     290578       NaN                1453.0                  1453.0
# 34007     938733  607802.0                1017.0                     NaN
# 34008     436264  306167.0                1017.0                     NaN
# 34009      11906    2504.0                1068.0                   437.0
# 34010   Возвраты       NaN                   NaN                     NaN
#
#        ID заказа  ID площадки Дата оформления заказа Время оформления заказа  \
# 0      6983378.0       4868.0             2022-11-28                   00:34
# 1      6983307.0       2576.0             2022-11-27                   22:57
# 2      6988162.0       5970.0             2022-11-29                   19:33
# 3      6978494.0       3921.0             2022-11-24                   16:35
# 4      6964523.0       3252.0             2022-11-17                   15:21
# ...          ...          ...                    ...                     ...
# 34006  6973701.0       3921.0             2022-11-22                   17:31
# 34007  6994333.0       3252.0             2022-12-02                   12:45
# 34008  6976926.0       3252.0             2022-11-24                   09:15
# 34009  6948115.0       3252.0             2022-11-09                   21:45
# 34010        NaN          NaN                   None                    None
#
#       Дата отгрузки товара Время отгрузки  ... Способ доставки  \
# 0               2022-12-03          18:15  ...       по городу
# 1               2022-12-04          08:26  ...       по городу
# 2               2022-12-02          10:42  ...       по городу
# 3               2022-12-01          18:17  ...     самовывовоз
# 4               2022-12-02          09:12  ...       по городу
# ...                    ...            ...  ...             ...
# 34006           2022-12-02          00:00  ...              ТК
# 34007           2022-12-03          00:00  ...       по городу
# 34008           2022-12-01          00:00  ...              ТК
# 34009           2022-12-01          00:00  ...              ТК
# 34010           2022-12-04           None  ...            None
#
#                           Транспортная компания Регион доставки  \
# 0                                          None          Москва
# 1                                          None   Новосибирская
# 2                                          None   Новосибирская
# 3                                          None            None
# 4                                          None   Новосибирская
# ...                                         ...             ...
# 34006                              АО "ДПД РУС"       Иркутская
# 34007                                      None   Новосибирская
# 34008                         ООО "СДЭК-ГЛОБАЛ"   Новосибирская
# 34009  ООО "Авиационное Транспортное Агентство"   Саха /Якутия/
# 34010                                      None            None
#
#           Город доставки                                     Адрес доставки  \
# 0                 Москва                 г Москва, ул Наташи Ковшовой, д 27
# 1            Новосибирск           г Новосибирск, ул Выборная, д 121, кв 68
# 2                Садовый  Пасечная, 4в, пос. Садовый, Новосибирский райо...
# 3                   None                                               None
# 4            Новосибирск  г Новосибирск, ул Немировича-Данченко, д 122, ...
# ...                  ...                                                ...
# 34006            Ангарск                   Ангарск, Микрорайон, 17а, д. 21а
# 34007        Новосибирск          г Новосибирск, ул Серебренниковская, д 13
# 34008  4 (рп Краснообск)  Россия, Новосибирская область, Краснообск, 2-й...
# 34009             Якутск                    г Якутск, ул Автодорожная, д 32
# 34010               None                                               None
#
#       Сумма НДС  Фирма-поставщик  Фирма-грузоотправитель  сборка/комплект  \
# 0        108.33           1462.0                  1462.0             None
# 1         91.83           1462.0                  1462.0             None
# 2        144.83           1462.0                  1462.0             None
# 3       1750.00           1462.0                  1462.0             None
# 4       2126.67           1462.0                  1462.0             None
# ...         ...              ...                     ...              ...
# 34006    116.67           1462.0                  1462.0             None
# 34007     33.33           1462.0                  1462.0             None
# 34008     39.17           1462.0                  1462.0             None
# 34009   2366.67           1462.0                  1462.0             None
# 34010       NaN              NaN                     NaN             None
#
#       Кол-во сборок
# 0              None
# 1              None
# 2              None
# 3              None
# 4              None
# ...             ...
# 34006          None
# 34007          None
# 34008          None
# 34009          None
# 34010          None
#
# [34011 rows x 32 columns]

# %%
df_fon.shape
# Out:
# (34011, 32)

# %%
df_fon[df_fon['Дата отгрузки товара'].astype(str) != pd.Timestamp.now().strftime( '%Y-%m-%d' )].shape
# Out:
# (17237, 32)

# %%
df_fon[df_fon['Дата отгрузки товара'].astype(str) == pd.Timestamp.now().strftime( '%Y-%m-%d' )] #['Дата отгрузки товара'] #.shape
# Out:
#       ID клиента   e2e4 ID  ID оформившего заказ  Ответственный менеджер  \
# 8         936098  606273.0                1017.0                     NaN
# 13         67495   48040.0                1017.0                   571.0
# 14        938525       NaN                1346.0                     NaN
# 16        913608  116856.0                1017.0                     NaN
# 17        892664       NaN                1222.0                     NaN
# ...          ...       ...                   ...                     ...
# 33972     938803       NaN                1137.0                     NaN
# 33976      53257       NaN                1433.0                  1622.0
# 33977     131130       NaN                1137.0                     NaN
# 33980     936160       NaN                1346.0                     NaN
# 33991     290578       NaN                1453.0                  1453.0
#
#        ID заказа  ID площадки Дата оформления заказа Время оформления заказа  \
# 8      6962682.0       3252.0             2022-11-16                   19:31
# 13     6964686.0       3252.0             2022-11-17                   16:10
# 14     6991491.0       3921.0             2022-12-01                   10:43
# 16     6957116.0       3252.0             2022-11-14                   15:28
# 17     7001458.0       3921.0             2022-12-05                   15:43
# ...          ...          ...                    ...                     ...
# 33972  7000019.0       3921.0             2022-12-05                   10:37
# 33976  6992916.0       3921.0             2022-12-01                   17:24
# 33977  6987268.0       3921.0             2022-11-29                   14:24
# 33980  6963168.0       3921.0             2022-11-17                   09:25
# 33991  6987584.0       3921.0             2022-11-29                   15:46
#
#       Дата отгрузки товара Время отгрузки  ... Способ доставки  \
# 8               2022-12-05          07:00  ...       по городу
# 13              2022-12-05          10:17  ...       по городу
# 14              2022-12-05          10:17  ...       по городу
# 16              2022-12-05          12:13  ...     самовывовоз
# 17              2022-12-05          15:44  ...     самовывовоз
# ...                    ...            ...  ...             ...
# 33972           2022-12-05          11:43  ...     самовывовоз
# 33976           2022-12-05          10:57  ...     самовывовоз
# 33977           2022-12-05          11:34  ...     самовывовоз
# 33980           2022-12-05          00:00  ...       по городу
# 33991           2022-12-05          00:00  ...              ТК
#
#        Транспортная компания Регион доставки Город доставки  \
# 8                       None      Приморский    Владивосток
# 13                      None       Алтайский        Барнаул
# 14                      None       Алтайский        Барнаул
# 16                      None            None           None
# 17                      None            None           None
# ...                      ...             ...            ...
# 33972                   None            None           None
# 33976                   None            None           None
# 33977                   None            None           None
# 33980                   None      Приморский    Владивосток
# 33991      ООО "СДЭК-ГЛОБАЛ"   Краснодарский      Геленджик
#
#                                  Адрес доставки Сумма НДС  Фирма-поставщик  \
# 8      г Владивосток, ул Русская, д 57М, кв 110    128.33           1462.0
# 13           г Барнаул, ул Новосибирская, д 16В    247.67           1462.0
# 14              г Барнаул, ул Балтийская, д 103     88.33           1462.0
# 16                                         None     85.00           1462.0
# 17                                         None     60.00           1462.0
# ...                                         ...       ...              ...
# 33972                                      None    183.33           1462.0
# 33976                                      None    150.00           1462.0
# 33977                                      None    266.67           1462.0
# 33980        г Владивосток, ул Часовитина, д 11     33.33           1462.0
# 33991     Геленджик, Южная промышленная зона, 7    116.67           1462.0
#
#        Фирма-грузоотправитель  сборка/комплект Кол-во сборок
# 8                      1462.0             None          None
# 13                     1462.0             None          None
# 14                     1462.0             None          None
# 16                     1462.0             None          None
# 17                     1462.0             None          None
# ...                       ...              ...           ...
# 33972                  1462.0             None          None
# 33976                  1462.0             None          None
# 33977                  1462.0             None          None
# 33980                  1462.0             None          None
# 33991                  1462.0             None          None
#
# [16774 rows x 32 columns]

# %%
del df_fon[df_fon['Дата отгрузки товара'].astype(str) == pd.Timestamp.now().strftime( '%Y-%m-%d' )]
df_fon.shpe
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_4127705/3886085182.py in <module>
# ----> 1 del df_fon[df_fon['Дата отгрузки товара'].astype(str) == pd.Timestamp.now().strftime( '%Y-%m-%d' )]
#       2 df_fon.shpe
#
# /opt/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/pandas/core/generic.py in __delitem__(self, key)
#    3961             # there was no match, this call should raise the appropriate
#    3962             # exception:
# -> 3963             loc = self.axes[-1].get_loc(key)
#    3964             self._mgr = self._mgr.idelete(loc)
#    3965
#
# /opt/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3359             casted_key = self._maybe_cast_indexer(key)
#    3360             try:
# -> 3361                 return self._engine.get_loc(casted_key)
#    3362             except KeyError as err:
#    3363                 raise KeyError(key) from err
#
# /opt/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /opt/anaconda3/envs/jupyter_env/lib/python3.9/site-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 34006    False
# 34007    False
# 34008    False
# 34009    False
# 34010    False
# Name: Дата отгрузки товара, Length: 34011, dtype: bool' is an invalid key

# %%
df_fon.shape
# Out:
# (34011, 32)

# %%
# pd.Timestamp.now().strftime( '%Y-%m-%d' )
df_fon = df_fon[df_fon['Дата отгрузки товара'].astype(str) != pd.Timestamp.now().strftime( '%Y-%m-%d' )]
df_fon.shape
# Out:
# (17237, 32)
